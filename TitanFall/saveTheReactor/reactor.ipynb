# %% [markdown]
# # Save the Reactor

# %%
import matplotlib.pyplot as plt
plt.title('battlefield top down view')
plt.plot(reactor_position[0], reactor_position[1], 'g*', label=f"reactor")
plt.plot(robo_pilot_position[0], robo_pilot_position[1], 'k*', label="robo pilot")
titan_x = []
titan_y = []
for position in titan_positions:
    titan_x.append(position[0])
    titan_y.append(position[1])
plt.plot(titan_x, titan_y, 'r.', label="Enemy Titans")
grunt_x = []
grunt_y = []
for position in grunt_positions:
    grunt_x.append(position[0])
    grunt_y.append(position[1])
plt.plot(grunt_x, grunt_y, 'b.', label = "Enemy Grunts")
pilot_x = []
pilot_y = []
for position in pilot_positions:
    if type(position[0]) == int:
        pilot_x.append(position[0])
        pilot_y.append(position[1])
    else:
        for pos in position:
            pilot_x.append(pos[0])
            pilot_y.append(pos[1])
plt.plot(pilot_x, pilot_y, 'r*', label="Enemy Pilots")

robo_pathx = []
robo_pathy = []
robo_pathx.append(robo_pilot_position[0])
robo_pathy.append(robo_pilot_position[1])
robo_pathx.append(7)
robo_pathy.append(9)
robo_pathx.append(6)
robo_pathy.append(11)
robo_pathx.append(2)
robo_pathy.append(4)
for path in grunt_positions:
    robo_pathx.append(path[0])
    robo_pathy.append(path[1]+1)
plt.plot(robo_pathx, robo_pathy, 'k', label="path to save the reactor")

import matplotlib.pyplot as plt
for line in predictpaths:
    xt = []
    yt = []
    for coord in line:
        if type(coord[0]) == type(1):
            
            xt.append(coord[0])
            yt.append(coord[1])
        else:
            for crd in coord:
                xt.append(crd[0])
                yt.append(crd[1])
    plt.plot(xt, yt, 'y--')
plt.plot(reactor_position[0],reactor_position[1],'y*',label="predicted enemy path")
plt.plot(reactor_position[0], reactor_position[1], 'g*')
plt.legend()
plt.show()
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b32839a0a476> in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.title('battlefield top down view')
# ----> 3 plt.plot(reactor_position[0], reactor_position[1], 'g*', label=f"reactor")
#       4 plt.plot(robo_pilot_position[0], robo_pilot_position[1], 'k*', label="robo pilot")
#       5 titan_x = []
#
# NameError: name 'reactor_position' is not defined

# %% [markdown]
# add titanfall datachain time based decision making here as mini game save the reactor

# %% [markdown]
# https://github.com/ethanpeacockaol/gemini_python/blob/main/Sin%20flow/my_animation.gif

# %% [markdown]
# see link above to copy solution for steppage of battle

# %%
from PIL import Image

def create_gif(image_paths, output_path, duration=200):
        """
        Creates a GIF from a list of image paths.

        Args:
            image_paths (list): List of image file paths.
            output_path (str): Path to save the output GIF.
            duration (int, optional): Duration of each frame in milliseconds. Defaults to 100.
        """
        frames = [Image.open(image_path) for image_path in image_paths]
        frames[0].save(output_path, save_all=True, append_images=frames[1:], duration=duration, loop=0)

    # Example usage:
name = 0
image_files = []
for i in range(k):
    image_files.append(f"imgs/{i}.png")
create_gif(image_files, 'my_animation.gif', duration=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-60f36b785a20> in <module>
#      16 name = 0
#      17 image_files = []
# ---> 18 for i in range(k):
#      19     image_files.append(f"imgs/{i}.png")
#      20 create_gif(image_files, 'my_animation.gif', duration=5)
#
# NameError: name 'k' is not defined
